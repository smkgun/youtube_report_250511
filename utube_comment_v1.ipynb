# %%
import pandas as pd
import random
import time
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from bs4 import BeautifulSoup
from urllib.parse import urlparse, parse_qs

def get_youtube_comments(video_url, max_comments=100, max_scrolls=10):
    options = Options()
    options.add_argument('--headless')
    options.add_argument('--disable-gpu')
    options.add_argument('--lang=ko-KR')
    options.add_argument('--no-sandbox')

    driver = webdriver.Chrome(options=options)
    driver.set_page_load_timeout(20)

    try:
        driver.get(video_url)
        time.sleep(3)

        scrolls = 0
        last_height = driver.execute_script("return document.documentElement.scrollHeight")
        for _ in range(max_scrolls):  # ✅ 최대 10번까지만 시도
            driver.execute_script("window.scrollTo(0, document.documentElement.scrollHeight);")
            time.sleep(2)
            new_height = driver.execute_script("return document.documentElement.scrollHeight")
            if new_height == last_height or len(driver.find_elements(By.ID, 'content-text')) >= max_comments:
                break
            last_height = new_height
            scrolls += 1

        soup = BeautifulSoup(driver.page_source, 'html.parser')
        comment_elems = soup.select('#content-text')
        comments = [c.text.strip() for c in comment_elems[:max_comments]]
    
    except Exception as e:
        print(f"❌ 댓글 로딩 중 예외 발생: {video_url}\n→ {e}")
        comments = []

    finally:
        driver.quit()

    return comments

def extract_video_id(url):
    parsed = urlparse(url)
    return parse_qs(parsed.query).get('v', [url.split("v=")[-1]])[0]

if __name__ == '__main__':
    input_file = 'youtube_metadata_김문수_후보_등록.csv'
    df = pd.read_csv(input_file)

    all_data = []

    for i, row in df.iterrows():
        video_url = row['url']
        video_id = extract_video_id(video_url)
        print(f"\n🎬 {i+1}/{len(df)} | {row['title']} | 채널: {row['channel']} | ID: {video_id}")

        try:
            comments = get_youtube_comments(video_url, max_comments=100)
            print(f"🗨️ {len(comments)}개 댓글 수집 완료")

            # ✅ 댓글 미리보기 3개
            if comments:
                print("📌 댓글 미리보기:")
                for preview in comments[:3]:
                    print(f"   - {preview}")
            else:
                print("⚠️ 댓글 없음 또는 비활성화 영상")

            for c in comments:
                all_data.append({
                    'videoId': video_id,
                    'title': row['title'],
                    'channel': row['channel'],
                    'comment': c
                })

        except Exception as e:
            print(f"❌ 오류 발생: {video_id} → {e}")

        # ✅ 영상 간 대기시간 랜덤화
        time.sleep(4 + random.uniform(0, 2))

    df_comments = pd.DataFrame(all_data)

    # ✅ 최종 미리보기
    print("\n📝 최종 댓글 통합 미리보기:")
    print(df_comments.head(3))

    df_comments.to_csv('youtube_comments_김문수_후보_등록.csv', index=False, encoding='utf-8-sig')
    print(f"\n✅ 총 댓글 수집 완료: {len(df_comments)}건 → youtube_comments_김문수_후보_등록.csv")
# Out:
# 🎬 1/50 | 김문수 후보등록 백브리핑 - 권영세가 사퇴한다 해놓고 사임을 안해~ 너 나가~~ | 채널: 유재일 | ID: 2NcIw1Ow3ss
# 🗨️ 8개 댓글 수집 완료
# 📌 댓글 미리보기:
#    - 한동훈대표님께 감사해야합니다
#    - 새로운 모습을 보았습니다 기적이 일어날거라 봅니다
#    - 아이구 답답
#
# 🎬 2/50 | 대선 판도 뒤흔드는 김문수, 등록과 갈등의 종지부! 김문수 대선 후보 등록 소식! | 채널: 생생정보 | ID: dnEa11ahuxo
# 🗨️ 0개 댓글 수집 완료
# ⚠️ 댓글 없음 또는 비활성화 영상
#
# 🎬 3/50 | 김문수, 대선 후보 등록! “기적이 일어났다”… 한덕수 전 총리와 만날 예정 | 채널: 팩트스팟FactSpot | ID: Cx8MeN9iG9E
# 🗨️ 2개 댓글 수집 완료
# 📌 댓글 미리보기:
#    - 하룻밤이 불안한 당~
# 하룻밤이 불안한 나이~~
#    - 승리절대못한다
#
# 🎬 4/50 | #리셋코리아 #대선후보등록#김문수 대통령 후보 | 채널: MARS | ID: iDBEVaw7mBI
# 🗨️ 1개 댓글 수집 완료
# 📌 댓글 미리보기:
#    - 승리합시다.자유민주주의 체재 수호 못하면 베네주엘라 직행입니다.
#
# 🎬 5/50 | #김문수, 선관위 후보등록…"반드시 당선돼 위대한 나라 만들 것""당원 투표, 놀라운 기적 일어나…한덕수, 잘 모시겠다"지도부 책임론에 "선거 며칠 안남아 화합해야, 빅텐트 중요 | 채널: 바람소리 : 진거무선 | ID: n7Ykax92B0I
# 🗨️ 2개 댓글 수집 완료
# 📌 댓글 미리보기:
#    - 힘내세요
#    - 뭐 하나 자연스럽지 않은 등록ᆢ
# 오물통속 등록ᆢ
#
# 🎬 6/50 | 국민의힘, 결국 김문수 후보로 대선 후보 등록하기로..권영세 "모든 책임지고 물러나겠다" [이슈PLAY] / JTBC News | 채널: JTBC News | ID: xzv1e7Yr5RY
# 🗨️ 10개 댓글 수집 완료
# 📌 댓글 미리보기:
#    - 극짐 내란당이 보수로보임?  제발좀 보수와 골수의 차이를 생각좀해요. 저들은 골수입니다. 자기이익만 생각하는 골수집합소
#    - 이제 한덕수는 수사 받고 감방행인가???
#    - JTBC ᆢ백다혜앵커님 감사합니다 ️
#
# 🎬 7/50 | 국민의힘 김문수 대선후보 등록…한덕수 “수용하고 승복” / KBS  2025.05.11. | 채널: KBS News | ID: ntsU1FPfo9Q
# 🗨️ 38개 댓글 수집 완료
# 📌 댓글 미리보기:
#    - 그렇게 강경하다가 너무나 순순히 물러나는 게 이상함. 법적으로 위법, 등록 무효인듯
#    - 한덕수 벼슬이 그리도 좋더냐
# 계엄도 못막은 무능함도 모른체 대선 후보에 욕심을 내다니
# 참 뻔뻔하고도 뻔뻔하구나
# 저 권성동이가 문제야!
#    - 김문수 지지합니다
#
# 🎬 8/50 | [속보] 국민의힘 김문수, 선관위 대선 후보 등록…정식 기호 2번 / YTN | 채널:  YTN | ID: kjxwTr_-YBA
# 🗨️ 22개 댓글 수집 완료
# 📌 댓글 미리보기:
#    - 이번 대선은 누가 되야 한다가 아니라 누가 되면 안된다의 싸움이다
#    - 자유 우파른
#    - 우,,,김문수 후보님 you did it,끝까지,, 화이팅
#
# 🎬 9/50 | 김문수 후보등록 현장 | 채널: 핫플 힐링로드 Hotple Healing Road | ID: GjLRjwRmt_M
# 🗨️ 17개 댓글 수집 완료
# 📌 댓글 미리보기:
#    - 당연한거아닌가 난 윤석열 국짐당 은 안찍을건데 그래도
# 정상적인게 바른거안닌가
#    - 김문수 승 축하합니다. 상대당 후보 비방보다는 자신들의 정책비젼 공약을 위주로 선거에 임하세요. 정정당당하게
#    - 왜 굳이...
#
# 🎬 10/50 | 후보 등록 마친 김문수 “위대한 나라 만드는 데 최선 다하겠다” | 채널: 오마이TV | ID: lYeFXQs1sqw
# 🗨️ 56개 댓글 수집 완료
# 📌 댓글 미리보기:
#    - 아저씨가 정당한 권리 다시 찾은 건 축하드리는데.
# 글쎄... 사이비 종교인하고 붙어먹은 사람을 대통령으로?
# 내란 옹호하던 사람을?
# 꿈도 크시네...
#    - 도와주셔서 감사합니다 위대한 대한민국 국민과
# 이재명 대통령이 만들겠습니다
#    - 위대한 나라는 당신이 신경 쓸 것 없고, 일단 그 국짐 집구석이나 단속을 하던 아님 해체 후 다시 새집을 짓던 해라.
#
# 🎬 11/50 | 김문수 '기호 2번' 후보 등록...텃밭 향하는 이재명 / YTN | 채널:  YTN | ID: gyQzks9Vmp4
# 🗨️ 51개 댓글 수집 완료
# 📌 댓글 미리보기:
#    - 이준석 성상납 은폐 노하우 태크닉 공개 부탁합니다.
#    - 쌍권 들은 사퇴해라. 자격 없다.
#    - 박상규 평론가님의 평론          객관성에 비추어 훌륭하시네요
#
# 🎬 12/50 | [다시보기] 김문수, 국힘 대선 후보 등록…"반드시 당선돼 위대한 나라 만들 것"-5월 11일 (일) 풀영상 [이슈현장] / JTBC News | 채널: JTBC News | ID: kyrpZ5ajdxQ
# 🗨️ 27개 댓글 수집 완료
# 📌 댓글 미리보기:
#    - 나라가 아니라 김문수를 위대하게 만드는거겠지
#    - 콩 심은데 콩나지 밭 나겠냐?  뉴라이트가 무슨 대한민국을 위한다고....일제시대면  또 모르지 ..
#    - 욕하러 왔는데 이미 욕밭이네
#
# 🎬 13/50 | 후보등록 마친 김문수,긴급입장문!김,지금 한덕수 전격회동-선대위원장 제안!!한덕수,적극협력의지 표명!신임 사무총장엔 4선 박대출의원! | 채널: 전옥현 안보정론TV | ID: x_nEXHezUvc
# 🗨️ 100개 댓글 수집 완료
# 📌 댓글 미리보기:
#    - 한덕수총리님
# 대단히 감사합니다
# 김후보님의
# 선대위원장 직을 고려해 보신다니
# 더욱 감사합니다
# 항상 존경하고 신뢰해온 총리님
# 부디 국가와 국민을 위해
# 다시 한번 더
# 힘들 자리를 수락하여
# 주시길 간곡히 부탁드립니다
# 50년 공직을 훌륭히
# 감당해 오신 총리님
# 끝까지 살신성인의 정신으로
# 애국하시는 모습을 국민들이
# 기억하고 역사의 중요한
# 총리님으로남으시길
# 기도합니다
#    - 권성동 자진탈당해야
#    - 대한민국 대통령님은  김문수입니다
# 김문수  홧팅!!!
#
# 🎬 14/50 | 밤사이 벌어진 반전…김문수 후보 기사회생 | 채널: 아는쇼핑 | ID: LmY_YBg1rpQ
# 🗨️ 0개 댓글 수집 완료
# ⚠️ 댓글 없음 또는 비활성화 영상
#
# 🎬 15/50 | 김문수가 찢었디!김문수후보등록완료!! 쌍권사태는사퇴로!! 한덕수품은김문수! #김문수 #한덕수 #단일화 #국민의힘 #대선후보 | 채널: 서민대표의 오늘의 키워드 | ID: -1ePGG7FXNA
# 🗨️ 0개 댓글 수집 완료
# ⚠️ 댓글 없음 또는 비활성화 영상
#
# 🎬 16/50 | 김문수, 후보 등록하고 한덕수와 포옹…이재명, 마지막 경청투어  / 연합뉴스TV (YonhapnewsTV) | 채널: 연합뉴스TV | ID: wwWKsRULcJw
# 🗨️ 13개 댓글 수집 완료
# 📌 댓글 미리보기:
#    - 끝까지 갑시다
# 두분에 좋은모습으로 해피엔딩 되엇내요
# 쌍권이 문제였을뿐 갑시다 대선승리까지요
#    - 대한민국을 사랑하는 애국시민
# 여러분의 후손을 생각하시고  나라를 생각해서 청백리요  적을알고 나를아는 영웅 김문수님을 도와
# 살기좋은 진정한
# 민주주의 나라를만듭시다,
#    - 김문수 대통령님 당선 되시면 어깨가 무겁겠습니다 곳곳에 부폐된곳 특히 선관위 사법부 공수처. 대청소 해 주시리라 믿습니다,대동단결!!  필승!!!
#
# 🎬 17/50 | 2025년 5월 11일   김문수 국민의힘 대통령후보 기호2번 등록  #김문수 #국민의힘  #shorts | 채널: 또박tv | ID: tR2gKzmm624
# 🗨️ 1개 댓글 수집 완료
# 📌 댓글 미리보기:
#    - 나이가 ㅋㅋㅋ75세?  국회의원도 나이 65세이상 금지 법안 만들어야된다.
# 오락가락 할나이 아닌가.ㅡ.ㅡ;;
#
# 🎬 18/50 | [뉴스초점] 김문수, 국힘 대선 후보 등록…이재명, 경청투어 마무리 / 연합뉴스TV (YonhapnewsTV) | 채널: 연합뉴스TV | ID: TQW78ZV7Uo0
# 🗨️ 29개 댓글 수집 완료
# 📌 댓글 미리보기:
#    - 김문수  후보의 살아온 삶이  시대의 영웅 으로  우뜩설것이다
#    - 권성동 원내대표  즉시사태하라
#    - 김문수후보  승리  승리  대선  확신합니다
#
# 🎬 19/50 | 김문수 후보 등록완료 한덕수 접견 | 채널: 해담풍 | ID: 5rjVDnWtDzU
# 🗨️ 0개 댓글 수집 완료
# ⚠️ 댓글 없음 또는 비활성화 영상
#
# 🎬 20/50 | 김문수, 대선 후보 등록 완료…“한덕수와 연대할 것” #뉴스 #이슈 #국민의힘 | 채널: K-News Clip | ID: dx4_7qvtGyc
# 🗨️ 0개 댓글 수집 완료
# ⚠️ 댓글 없음 또는 비활성화 영상
#
# 🎬 21/50 | 한국 최초(?) 새벽 3시 20분 입당 | 채널: TBC뉴스 | ID: bCymmqiP1j0
# 🗨️ 4개 댓글 수집 완료
# 📌 댓글 미리보기:
#    - 국힘이 순진한 70대 노인 꼬드겨 1만원을 갈취한 사건
#    - 조태경 너는 별로 보고싶지않다
# 나대지말길
#    - 경태야 넘어가라
#
# 🎬 22/50 | [김문수] 후보 등록 생중계 | 채널: 윤어갠 | ID: 3jL5Z-B2Jms
# 🗨️ 1개 댓글 수집 완료
# 📌 댓글 미리보기:
#    - 김문수 후보를 응원합니다
# 늦게 출발한 만큼 한발 더
# 뛰시고 국민들도 뭉쳐서
# 자유 대한민국을 지킵시다
#
# 🎬 23/50 | 김문수 후보등록 | 채널: 정치가싫다 | ID: YpJMmEMLoi4
# 🗨️ 8개 댓글 수집 완료
# 📌 댓글 미리보기:
#    - ㅋ 이게 정당이 맞나 싶네. 편을 들어줄 수가 없을 정도로 쪽팔려~
#    - 당비 1만원 ㅋㅋㅋㅋㅋ,,,
#    - ㅉㅉ 망신만 당하고
# 끝나는 구만~~
#
# 🎬 24/50 | [생방송] 김문수 선관위에 대선후보 등록! 권영세 비대위원장 사퇴! 한덕수 김문수 돕겠다! 홍준표 김문수 선전 기대! 250511 #코리아드림뉴스 | 채널: 코리아드림뉴스 | ID: e2H6sjxz0jY
# 🗨️ 1개 댓글 수집 완료
# 📌 댓글 미리보기:
#    - 킹문수 만세~
# 무조건 김문수로 갑시다
#
# 🎬 25/50 | 🌹김문수, 선관위 후보등록... #국힘당 #김문수후보 | 채널: 우주빛김성한방송[HAN] | ID: 3v3R9ya7ZkU
# 🗨️ 0개 댓글 수집 완료
# ⚠️ 댓글 없음 또는 비활성화 영상
#
# 🎬 26/50 | 국힘, 한덕수 하차?! 당원 투표 부결로 김문수 즉시 자격 회복... #쇼츠뉴스 #단신뉴스 #국민의힘 #한덕수 #김문수 | 채널: 소소상 | ID: D2gWf9H9wDk
# 🗨️ 0개 댓글 수집 완료
# ⚠️ 댓글 없음 또는 비활성화 영상
#
# 🎬 27/50 | 김문수 후보 등록 완료 승리 하겠다! | 채널: 냥냥사랑 | ID: xZQkUclQyMY
# 🗨️ 83개 댓글 수집 완료
# 📌 댓글 미리보기:
#    - 김문수대통령당선예감입니다.
# 응원 열심히 하겠습니다.
#    - ..김문수 님  이제부터  이죄명 처럼  악랄 하게   운동하십시요..힘내십시요
#    - 쬐명이 를 이길수있는!
# 김문수 대통령
#
# 🎬 28/50 | [🔴속보] '기사회생' 김문수, 국민의힘 대선 후보 등록 "막중한 책임…반드시 당선돼 위대한 대한민국 만들 것"｜"지도부 방향 강하게 작용했지만 이겨내" | 채널: 연합뉴스TV | ID: mx7SRG8kuC0
# 🗨️ 2개 댓글 수집 완료
# 📌 댓글 미리보기:
#    - 되겠냐 ㅋㅋㅋ홍준표를 버렷는데
#    - 일단은 축하하고 민주당지지자들이 엄청나게 도와줬으니까    이재명 씹는 유세 하지말고  정잭위주로  유세 해야  될듯
# 이재명대표가  김문수 동생 변호도  무료로  해줬다 더만
#
# 🎬 29/50 | 김문수 국힘 후보 등록 | 채널: 건정소 | ID: to5YoykEBIc
# 🗨️ 9개 댓글 수집 완료
# 📌 댓글 미리보기:
#    - 문수후보님화이팅꼭대통령되서나라살려주세요맘고생많았읍니다
#    - 대통이 된다고. 헐.
#    - 이시국에 문수가 적격이다
#
# 🎬 30/50 | 🔴[LIVE] 김문수 "선대위원장을 맡아주시면..." 한덕수 대답은? / 후보 등록 마친 김문수, 한덕수와 회동  25.05.11 | MBN NEWS | 채널: MBN News | ID: Cm4JV4UMiVE
# 🗨️ 0개 댓글 수집 완료
# ⚠️ 댓글 없음 또는 비활성화 영상
#
# 🎬 31/50 | 김문수 대선 후보 등록 완료…한덕수와 손잡고 ‘국난 극복’ 선언 | 채널: shortoryvibe | ID: unymhTj8epo
# 🗨️ 0개 댓글 수집 완료
# ⚠️ 댓글 없음 또는 비활성화 영상
#
# 🎬 32/50 | 한덕수 덕에 살빠진 김문수..  대선후보 등록 끝.... #김문수 #국민의힘 #한덕수 #대선후보 | 채널: 이슈?있슈~ | ID: 0uLT3_bclJ4
# 🗨️ 0개 댓글 수집 완료
# ⚠️ 댓글 없음 또는 비활성화 영상
#
# 🎬 33/50 | [🔴생중계] 김문수·한덕수 회동…"잘 모시겠다" "꼭 승리해달라"｜이 시각 국민의힘 당사/ 연합뉴스TV(YonhapnewsTV) | 채널: 연합뉴스TV | ID: vz92JZnECLs
# 🗨️ 0개 댓글 수집 완료
# ⚠️ 댓글 없음 또는 비활성화 영상
#
# 🎬 34/50 | 투사 김문수후보 - 중앙선거관리위원회 후보등록 | 채널: 상진 | ID: g-Iv7gIR5M8
# 🗨️ 34개 댓글 수집 완료
# 📌 댓글 미리보기:
#    - 역시 우리 신자유연대 김상진대표가 옳았다 으샤으샤
# 김문수후보님 화이팅
#    - 이재명 이길사람 김문수후보님
#    - 윤어게인
# 김문수 화이팅
#
# 🎬 35/50 | 후보 변경 당원 찬반투표에서 부결. 김문수 오늘 후보 등록 | 채널: 예능하나 | ID: uuAXsaYISTU
# 🗨️ 1개 댓글 수집 완료
# 📌 댓글 미리보기:
#    - 한덕수는 김문수후보를 도와라.
# 그렇치 않으면 명예회복 힘들것이다.진정 나라를 지킨다면 김문수를 도와라
#
# 🎬 36/50 | [스팟Live] 후보 등록 마친 김문수, 한덕수 접견 생중계 | 25.05.11 | 채널: 뉴스핌TV | ID: zv2Mrho0XtM
# 🗨️ 0개 댓글 수집 완료
# ⚠️ 댓글 없음 또는 비활성화 영상
#
# 🎬 37/50 | (속보) 국힘당 김문수 오늘 후보 등록! 한덕수 국민께 마지막 인사! 하룻밤 사이에 또 바뀌었다! | 채널: 바꿀수만있다면TV | ID: jLe_j7MsAvg
# 🗨️ 9개 댓글 수집 완료
# 📌 댓글 미리보기:
#    - 이재명 과 김문수의 대결은 .....
# 선 과 악
# 또는
# 진짜 "독종" 끼리 만났다고 본다.
#
# 둘다 노동운동을 기반으로 컸지만
# 이재명은 끝까지 시민과 함께....
# 김문수는 ......(군),검찰세력과 함께
# 배부르고 등 따수운  정치를 한 결과를 평가 받는다.
#    - 꼴렐루야
# 국힘은 전광훈이 접수한다..
#    - 과거를 보면 그사람 정체를 알수있다
# 사람은 변하지 않는다 사람은 고쳐쓰지않는다 그냥 버릴뿐이지
#
# 🎬 38/50 | 🔴LIVE 김문수 국민의힘 대통령후보 등록 / 이 시각 중앙선관위 / 25.5.11 / KNN | 채널: KNN NEWS | ID: qpOW7S3Bcaw
# 🗨️ 14개 댓글 수집 완료
# 📌 댓글 미리보기:
#    - 이제는 김문수후보 중심으로 단합하여 반드시 승리 합시다 화이팅
#    - 누굴탓하지 말고
# 이죄명만은 안되도록 무조건 힘을 합하여 단합만이 답이다
#    - 김문수후보님 함께 하겠습니다
#
# 🎬 39/50 | [현장연결] 국민의힘 김문수 직접 후보 등록…"반드시 당선돼 위대한 나라 만들 것" / 연합뉴스TV (YonhapnewsTV) | 채널: 연합뉴스TV | ID: Xv9gWBmc8AI
# 🗨️ 100개 댓글 수집 완료
# 📌 댓글 미리보기:
#    - 갓문수였네 사람이 완전 커보이고 달리보이네요
#    - 김문수후보님 꼭 대통령도셔서 위대하고 살기좋은 자유대한민국 만들어주세요. 기대하고있습니다.
#    - 잘 하실것 같네요!
# 청렴하고 진심이 느껴집니다!
#
# 🎬 40/50 | 국힘, 기습 후보 교체 실패 김문수 대선 후보 등록 | 채널: 정치썰전 | ID: AaBTM6jWTSc
# 🗨️ 2개 댓글 수집 완료
# 📌 댓글 미리보기:
#    - 결국 해내는구나
#    - 매국노 두 새끼가 싸우더니 한 새끼가 하는구나.
# 저런 매국노 쓰레기가 후보로 나온다는 자체가 코메디다.
# 저런 쓰레기에 대갈통을 처단해야 한다.
#
# 🎬 41/50 | [HOT 이슈메이커] ＜후보 자격 회복 김문수 11일 공식 후보 등록＞　김문수 지지자 최강욱! “이거슨 김문수의 30년 플랜이다!” | 채널: 오마이TV | ID: bAc6YywOZS4
# 🗨️ 16개 댓글 수집 완료
# 📌 댓글 미리보기:
#    - 한덕수  입당 기탁금  1만원은  ?  돌려 줘야  할텐데
#    - 한덕수가 제일 나쁜놈인건 판단을 유보하겠지만 현재까지 봤을때..
# 역사적으로도 최고로 비열한 인간아닌가 싶다 너무너무 싫다 저 케릭터 에이 퉤퉤
#    - 박영식 앵커 목소리 듣기좋고 명확.정확ㅇ전달력 ~~ 코믹도겸비 ~~ 앞으로도 승승장구하세요
#
# 🎬 42/50 | [🔴속보] 김문수, 오늘 공식 후보 등록…국힘 "당 지도부, 정치적으로 다 함께 책임 질 것" / 연합뉴스TV(YonhapnewsTV) | 채널: 연합뉴스TV | ID: U6OPBdpvFD4
# 🗨️ 5개 댓글 수집 완료
# 📌 댓글 미리보기:
#    - 권성동은 사퇴안해? 알랑한 원대대표 자리 그만 붙잡고..
#    - 쌍권씨들은 책임지고 물러난거면 다신 돌아오지마라. 그게 나라와 국민을 위하는 길이다.
#    - 쌍권 뒤에 숨어 동조한 국힘 의원들도 많습니다. 이제 모든게 정상으로 돌아왔으니 김문수에 관심 끝. 이재명 뽑아야지.
#
# 🎬 43/50 | [국민의힘] 김문수, 선관위서 '국민의힘 대선 후보' 등록 | 채널: BBfa | ID: _a019vMOLaE
# 🗨️ 0개 댓글 수집 완료
# ⚠️ 댓글 없음 또는 비활성화 영상
#
# 🎬 44/50 | 국민의 힘 후보교체 ‘부결’ 김문수 대선후보 등록 #김문수 #국민의힘 #쿠데타실패 | 채널: 아라치정보 | ID: YmISce_cEvU
# 🗨️ 1개 댓글 수집 완료
# 📌 댓글 미리보기:
#    - 이건 생각이 없이 진행했어
# 쌍권이랑 석열이 작품이었는데
# 안된거지 ㅋ
#
# 🎬 45/50 | 김문수 후보!선관위에 대통령후보 등록!! | 채널: 이수옥TV | ID: UH1T0KQ30YI
# 🗨️ 1개 댓글 수집 완료
# 📌 댓글 미리보기:
#    - 이제 하나되어 선거에서 꼭 승리 하기를 빕니다
#
# 🎬 46/50 | 🔴LIVE 김문수 국민의힘 대통령후보 등록 / 이 시각 중앙선관위 / 25.5.11 / KNN | 채널: KNN NEWS | ID: ADtHxh69yYo
# 🗨️ 8개 댓글 수집 완료
# 📌 댓글 미리보기:
#    - 믿음직한 모습입니다. 국운이 다시한번 돌아 오려나 봅니다..
#    - 정직.의리.청렴.용기의 지도자 김문수 후보님 강력지지합니다!!
#    - 이제 똘똘뭉쳐 이기자.
#
# 🎬 47/50 | [현장영상+] 국민의힘 김문수, 선관위 대선 후보 등록...정식 기호 2번 / YTN | 채널:  YTN | ID: PClLKIQM1gk
# 🗨️ 37개 댓글 수집 완료
# 📌 댓글 미리보기:
#    - 한밤중 후보교체 주동자들 다 나가라
# 그래야 당이 개혁이 되지
#    - 김문수 후보님 잘하셨습니다ㆍ
#    - 쌍권과 한덕수의 추한 모습으로 대권주자 김문수가 더욱 빛났다
#
# 🎬 48/50 | [🔴LIVE] 국민의힘 김문수 대통령 후보 등록 선관위 생중계/2025년 5월 11일(일)/KBS | 채널: KBS News | ID: CGt9MQPt0Qc
# 🗨️ 0개 댓글 수집 완료
# ⚠️ 댓글 없음 또는 비활성화 영상
#
# 🎬 49/50 | [다시보기] 국힘 당원투표서 '한덕수 후보 등록' 부결-5월 10일 (토) 풀영상 [이슈현장] / JTBC News | 채널: JTBC News | ID: brKZv36aJA4
# 🗨️ 53개 댓글 수집 완료
# 📌 댓글 미리보기:
#    - 석열의 난 - 덕수의 난 - 상목의 난 - 2차 덕수의 난 - 희대의 난 - 쌍권의 난, 모두 진압
#    - 두 권 다 나가야지?
# 왜? 한 권만 남죠
#    - 세상 사람들의 욕을 그렇게나 먹으면서도 끝까지 권력의 미련을 못놓는구나.. 권력이 대단한겨..
#
# 🎬 50/50 | 🔴국민의힘 김문수 후보직 복귀..대통령 후보 등록 | SBS 실시간 LIVE | 채널: SBS 뉴스 | ID: B5x0zXapa3o
# 🗨️ 0개 댓글 수집 완료
# ⚠️ 댓글 없음 또는 비활성화 영상
#
# 📝 최종 댓글 통합 미리보기:
#        videoId                                         title channel  \
# 0  2NcIw1Ow3ss  김문수 후보등록 백브리핑 - 권영세가 사퇴한다 해놓고 사임을 안해~ 너 나가~~     유재일
# 1  2NcIw1Ow3ss  김문수 후보등록 백브리핑 - 권영세가 사퇴한다 해놓고 사임을 안해~ 너 나가~~     유재일
# 2  2NcIw1Ow3ss  김문수 후보등록 백브리핑 - 권영세가 사퇴한다 해놓고 사임을 안해~ 너 나가~~     유재일
#
#                        comment
# 0              한동훈대표님께 감사해야합니다
# 1  새로운 모습을 보았습니다 기적이 일어날거라 봅니다
# 2                       아이구 답답
#
# ✅ 총 댓글 수집 완료: 766건 → youtube_comments_김문수_후보_등록.csv
